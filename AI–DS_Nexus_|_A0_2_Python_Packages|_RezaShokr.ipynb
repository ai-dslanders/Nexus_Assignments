# %% [markdown]
# <a href="https://colab.research.google.com/github/MahdiGholami1992/Nexus_Assignments/blob/main/AI%E2%80%93DS_Nexus_%7C_A0_2_Python_Packages%7C_RezaShokr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📚 Assignment 2 — NumPy, pandas & Matplotlib Essentials
# Welcome to your first data-science sprint! In this three-part mini-project you’ll touch the libraries every ML practitioner leans on daily:
#
# 1. NumPy — fast n-dimensional arrays
#
# 2. pandas — tabular data wrangling
#
# 3. Matplotlib — quick, customizable plots
#
# Each part starts with “Quick-start notes”, then gives you two bite-sized tasks. Replace every # TODO with working Python in a notebook or script, run it, and check your results. Happy hacking! 😊

# %% [markdown]
# ## 1 · NumPy 🧮
# Quick-start notes
# Core object: ndarray (n-dimensional array)
#
# Create data: np.array, np.arange, np.random.*
#
# Summaries: mean, std, sum, max, …
#
# Vectorised math beats Python loops for speed

# %% [markdown]
# ### Task 1 — Mock temperatures

# %%
# 👉 # TODO: import numpy and create an array of 365
# normally-distributed °C values (µ=20, σ=5) called temps
import numpy  as np

temps = np.random.normal(loc=20, scale=5, size=365)
print(temps)
# Out:
# [13.94109589 17.05872985 22.71620203 14.83123281 12.66252443 18.00669719
#  14.23310077 19.00817835 15.08869148 14.10597194 21.05674241 22.36505533
#   9.72008107 25.01519843 13.43447641 19.43780148 10.81379206 14.67957984
#  23.74653022 20.61510619 22.2251898  25.82643025 21.13847625 19.97401937
#  16.50592865 16.24598723 16.97891556 20.35397915 17.63740092 19.79052058
#  13.24748608 30.382       9.60681625 29.49808194 14.54091429 14.2409985
#  25.81050107 15.99395499 25.10166704 23.38152569 12.08024934 30.59340206
#  28.41149525 23.33325273  9.41715745 16.94538401 30.65076615 20.67361581
#  12.94592682 20.78793008 32.15130401 18.75941704 30.32959058 29.70149324
#  22.41773442 19.98181883 23.4993289   8.41264086 27.41037892 12.89705866
#  17.62847463 20.66909353 28.61224428 18.79259968 26.78407205 22.36654749
#   7.44737797 14.04719858 25.02857155 15.80545974 15.13353476 17.24900599
#  16.34124238 19.26973838 21.72274724 19.37869404 19.13203406 23.3444075
#  17.72494027 24.19325617 16.6552437  23.99283507 15.05946676 19.93979062
#  18.90238537 22.04839663 27.90963983 19.76148654 21.37098655 20.27896102
#  18.78995524 13.05624189 25.54909173 15.0134177  26.60768563 13.18093353
#  13.64593354 18.7183139  15.38758615 17.19969717 19.88666206 26.72968063
#  21.96849235 28.71708593 17.35139944 11.13654549 23.13464291 10.94194024
#  22.61692405 19.06546875 27.16974885 20.05831008 18.62086737 16.03470456
#  16.08089953 25.14358377 12.46306303 17.71849915 24.10886855 24.55942727
#  17.29999385 23.37480322 10.85710723 25.48969959 11.9152461  17.30107101
#  13.74540421 24.60144335 25.11562975 17.0942585  21.16202761 16.62077536
#  24.97466223 23.64954375 25.31866379 12.13539638 21.09802735 20.56200468
#  20.09649237 19.34466826 11.03578565 31.22843747 17.39965635]

# %% [markdown]
# ### Task 2 — Average temperature

# %%
# 👉 # TODO: print the mean of temps
import numpy as np

temps = np.random.normal(loc=20, scale=5, size=365)

average_temp = np.mean(temps)
print("average temp:", average_temp)
# Out:
# average temp: 20.26769376015348

# %% [markdown]
# ## 2 · pandas 📊
# Quick-start notes
# Main structures: DataFrame, Series
#
# Read data: pd.read_csv, pd.read_excel, …
#
# Selection: .loc[label], .iloc[pos]
#
# Group & summarise: .groupby(...).agg(...)

# %% [markdown]
# ### Task 3 — Load ride log

# %%
# 👉 # TODO: read "rides.csv" into df
# (columns: date,temp,rides,weekday)
import pandas as pd
dates = pd.date_range(start="2025-07-01", periods=365)
temps = np.random.normal(loc=20, scale=5, size=365).round(1)
rides = np.random.randint(100, 500, size=365)
weekdays = dates.day_name()
df = pd.DataFrame({
    "date": dates,
    "temp": temps,
    "rides": rides,
    "weekday": weekdays
})
print(df.head())
df.to_csv('/content/sample_data/rides.csv')


df = pd.read_csv("/content/sample_data/rides.csv")
print(df.head())
# Out:
#         date  temp  rides    weekday
# 0 2025-07-01  30.6    306    Tuesday
# 1 2025-07-02  25.7    167  Wednesday
# 2 2025-07-03  17.9    308   Thursday
# 3 2025-07-04  13.5    284     Friday
# 4 2025-07-05  10.0    410   Saturday
#    Unnamed: 0        date  temp  rides    weekday
# 0           0  2025-07-01  30.6    306    Tuesday
# 1           1  2025-07-02  25.7    167  Wednesday
# 2           2  2025-07-03  17.9    308   Thursday
# 3           3  2025-07-04  13.5    284     Friday
# 4           4  2025-07-05  10.0    410   Saturday

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Task 4 — Weekday averages

# %%
# 👉 # TODO: compute and print mean rides per weekday
mean_rides = df.groupby("weekday")["rides"].mean()
print(mean_rides)
# Out:
# weekday
# Friday       298.076923
# Monday       332.211538
# Saturday     310.942308
# Sunday       307.519231
# Thursday     291.115385
# Tuesday      294.735849
# Wednesday    292.096154
# Name: rides, dtype: float64

# %% [markdown]
# ## 3 · Matplotlib 📈
# Quick-start notes
# Workhorse: pyplot interface (import matplotlib.pyplot as plt)
#
# Figure & axes: fig, ax = plt.subplots()
#
# Common plots: plot, scatter, hist, imshow
#
# Display inline in Jupyter with %matplotlib inline or %matplotlib notebook

# %% [markdown]
# ### Task 5 — Scatter plot

# %%
# 👉 # TODO: scatter-plot temperature (x) vs rides (y) from df

import matplotlib.pyplot as plt

plt.scatter(df["temp"], df["rides"], alpha=0.6)

# %% [markdown]
# ### Task 6 — Show the figure

# %%
# 👉 # TODO: call plt.show() so the plot appears

import matplotlib.pyplot as plt

plt.scatter(df["temp"], df["rides"], alpha=0.6)
plt.xlabel("Temperature (°C)")
plt.ylabel("Number of Rides")
plt.title("Temperature vs Rides")
plt.grid(True)
plt.show()
